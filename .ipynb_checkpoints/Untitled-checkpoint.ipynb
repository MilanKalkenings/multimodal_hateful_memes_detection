# %%
import pandas as pd
import torch

df_train = pd.read_pickle("../hateful_memes_data/preprocessed_train_v2.pkl")
#df_train = pd.read_pickle("../misogyny_data/preprocessed_train_v2.csv")

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
df_train = pd.read_pickle("../hateful_memes_data/preprocessed_train_v2.pkl")

# %%
for i, text in enumerate(df_train["text"]):
    if "iron" in text.split():
        image = Image.open("../hateful_memes_data/" + df_train["img"][i]).convert("RGB")
        plt.imshow(image)
        print(df_train["img"][i])
        plt.show()
# Out:
# img/45836.png
# img/09187.png
# img/09768.png
